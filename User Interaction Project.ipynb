# %%
game_list = [0,1,2,3,4]

# %%
def display_game(game_list):
    print("Here is the current list")
    print (game_list)

# %%
display_game(game_list)
# Out:
# Here is the current list
# [0, 1, 2, 3, 4]

# %%
def position_choice():
    
    choice = 'wrong'
    
    while choice not in ['0','1','2','3','4']:
        
        choice = input ("Pick a position to replace (0,1,2,3,4): ")
    
    if choice not in ['0','1','2','3','4']:
        
        print ("Sorry, invalid choice!")
        
    return int(choice)

# %%
position_choice()
# Out:
# Pick a position to replace (0,1,2,3,4): 4
# 4

# %%
def replacement_choice(game_list,position):
    
    user_replacement = input("Type a string to place at position:")
    
    game_list[position]=user_replacement
    
    return game_list

# %%
replacement_choice(game_list,1)
# Out:
# Type a string to place at position:test
# [0, 'test', 2, 3, 4]

# %%
def gameon_choice():
    
    choice = 'wrong'
    
    while choice not in ['Y','N']:
        
        choice = input ("Keep playing? (Y or N) ")
    
    if choice not in ['Y','N']:
        
        print ("Sorry, I don't understand, please choose Y or N")
        
    if choice == "Y":
        return True
    else:
        return False

# %%
gameon_choice()
# Out:
# Keep playing? (Y or N) Y
# True

# %%
game_on = True
game_list = [0,1,2,3,4]

while game_on:
    
    display_game(game_list)
    
    position = position_choice()
    
    game_list = replacement_choice(game_list,position)
    
    display_game(game_list)
    
    game_on = gameon_choice()
# Out:
# Here is the current list
# [0, 1, 2, 3, 4]
# Pick a position to replace (0,1,2,3,4): 8
# Pick a position to replace (0,1,2,3,4): 89
# Pick a position to replace (0,1,2,3,4): 5
# Pick a position to replace (0,1,2,3,4): 4
# Type a string to place at position:i
# Here is the current list
# [0, 1, 2, 3, 'i']
# Keep playing? (Y or N) Y
# Here is the current list
# [0, 1, 2, 3, 'i']
# Pick a position to replace (0,1,2,3,4): 7
# Pick a position to replace (0,1,2,3,4): t
# Pick a position to replace (0,1,2,3,4): 4
# Type a string to place at position:3
# Here is the current list
# [0, 1, 2, 3, '3']
# Keep playing? (Y or N) y
